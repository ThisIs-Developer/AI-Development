# %%
#Question 1
print("Baivab Sarkarr")
print("Kazidanaga,Bandel")
print("P.O Debanandapur,P.S Chinsura")
print("Hooghly,West Bengal,712123,India")
print("Telephone: 8961428548")
print("E-Mail: baivabsarkar@gmail.com")
# Out:
# Baivab Sarkarr
# Kazidanaga,Bandel
# P.O Debanandapur,P.S Chinsura
# Hooghly,West Bengal,712123,India
# Telephone: xxxxxxxx48
# E-Mail: baivabsarkar@gmail.com

# %%
#Question 2
NAME=str(input("Enter your name: "))
print("Hello",NAME)
# Out:
# Enter your name: Baivab Sarkar
# Hello Baivab Sarkar

# %%
#Question 3
width=float(input("Enter the width (feet): "))
length=float(input("Enter the length (feet): "))
area = width*length
print("Area: ",area, "square feet")
# Out:
# Enter the width (feet): 90.5
# Enter the length (feet): 65.3
# Area:  5909.65 square feet

# %%
#Question 4
width=float(input("Enter the width (feet): "))
length=float(input("Enter the length (feet): "))
squarefeet= 43560 
acres = (length*width) / squarefeet 
print("Area: ",acres, "acres")
# Out:
# Enter the width (feet): 1300
# Enter the length (feet): 1500
# Area:  44.76584022038568 acres

# %%
#Question 5
Less_one_litter = 0.10
More_one_litter = 0.25
less=int(input("How many containers one litre or less: ")) 
more=int(input("How many containers more than one litre: ")) 
refund = less * Less_one_litter + more * More_one_litter
print ("Refund: $%.2f."%refund)
# Out:
# How many containers one litre or less: 5
# How many containers more than one litre: 6
# Refund: $2.00.

# %%
#Question 6
Price=float(input("Enter the price of the meal: "))
Tax_rate = 0.05 
Tip_rate = 0.18 
tax= Price*Tax_rate
tip= Price*Tip_rate 
total= (Price+tax+tip)
print ("The tax is %.2f and the tip is %.2f, making the total %.2f"%(tax, tip, total))
# Out:
# Enter the price of the meal: 140
# The tax is 7.00 and the tip is 25.20, making the total 172.20

# %%
#Question 7
n=int(input("Enter a positive integer: ")) 
sum = n*(n+1)/2 
print("The sum of the first",n,"positive integers: ", sum)
# Out:
# Enter a positive integer: 25
# The sum of the first 25 positive integers:  325.0

# %%
#Question 8
#Widgets=75 grams
#Gizmos=112 grams
Widgets=int(input("Enter your number of Widgets: "))
Gizmos=int(input("Enter your number of Gizmos: "))
weight_of_widgets= Widgets*75
weight_of_gizmos= Gizmos*112
totalWeight= weight_of_widgets + weight_of_gizmos
print ("The total weight of the order: ",totalWeight,"grams")
# Out:
# Enter your number of Widgets: 8
# Enter your number of Gizmos: 5
# The total weight of the order:  1160 grams

# %%
#Question 9
Deposite=float(input("Enter the Amount = "))
interest=0.04
year=1
for i in range(0,3):
  Total= Deposite*(1+interest) ** year
  year=year+1
  print("Amount in the savings-account after",year-1,"year: %.2f"%Total)
# Out:
# Enter the Amount = 100
# Amount in the savings-account after 1 year: 104.00
# Amount in the savings-account after 2 year: 108.16
# Amount in the savings-account after 3 year: 112.49

# %%
#Question 10
import math
from math import log10
a=int(input("Enter the value of a: "))
b=int(input("Enter the value of b: "))
print("a + b :",a+b)
print("a - b :",a-b)
print("a * b :",a*b)
print("a / b :",a/b)
print("log10 a :",log10(a))
print("a ^ b :",a^b)
# Out:
# Enter the value of a: 10
# Enter the value of b: 20
# a + b : 30
# a - b : -10
# a * b : 200
# a / b : 0.5
# log10 a : 1.0
# a ^ b : 30

# %%
#Question 11
miles_pergallon=float(input("Enter the fuel efficiency in US :"))
liters_per_hundred_kilometers= (235.215/miles_pergallon)
print("Fuel efficiency in Canada :",liters_per_hundred_kilometers)
# Out:
# Enter the fuel efficiency in US :25
# Fuel efficiency in Canada : 9.4086

# %%
#Question 12
import math
from math import radians, sin, cos, acos
print("Enter the first longitude and latitude on the Earth in degrees:")
lon1 = radians(float(input("Longitude 1 : ")))
lat1 = radians(float(input("Latitude 1 : ")))
print("Enter the second longitude and latitude on the Earth in degrees:")
lon2 = radians(float(input("Longitude 2 : ")))
lat2 = radians(float(input("Latitude 2 : ")))

distance = 6371.01 * acos(sin(lat1)*sin(lat2) + cos(lat1)*cos(lat2) * cos(lon1 - lon2))
print("Distance is: %.2fkm." %distance)
# Out:
# Enter the first longitude and latitude on the Earth in degrees:
# Longitude 1 : 134.25
# Latitude 1 : 57.45
# Enter the second longitude and latitude on the Earth in degrees:
# Longitude 2 : 174.25
# Latitude 2 : 53.48
# Distance is: 2521.60km.

# %%
#Question 13(12)
cents=int(input('Enter the no. of cents: '))
print(f'The changes ::\n')
print(f'{cents//200} toonies')
cents=cents%200
print(f'{cents//100} loonies')
cents=cents%100
print(f'{cents//25} quarters')
cents=cents%25
print(f'{cents//10} dimes')
cents=cents%10
print(f'{cents//5} nickles')
cents=cents%25
print(f'{cents//1} pennies')
# Out:
# Enter the no. of cents: 500
# The changes ::
#
# 2 toonies
# 1 loonies
# 0 quarters
# 0 dimes
# 0 nickles
# 0 pennies

# %%
#Question 14(13)
ft = int(input("Enter your hieght in Feet : "))
inch = int(input("Enter your hieght in Inches : "))
inch+= (ft*12)
cm = (inch*2.54)
print("Your height is : %d cm11" %cm)
# Out:
# Enter your hieght in Feet : 5
# Enter your hieght in Inches : 11
# Your height is : 180 cm

# %%
1#Question 15(14)
ft = int(input("Enter the distance in feet : "))
inches = ft * 12
yards = ft / 3.0
miles = ft / 5280.0
print("The distance in inches : %i inches." % inches)
print("The distance in yards : %.2f yards." % yards)
print("The distance in miles : %.2f miles." % miles)
# Out:
# Enter the distance in feet : 50
# The distance in inches : 600 inches.
# The distance in yards : 16.67 yards.
# The distance in miles : 0.01 miles.

# %%
#Question 16(15)
import math
from math import pi
radius = float(input ("Enter the radius(r) : "))
area= (pi*radius**2)
print("The area of the circle is : %.3f"%area)
volume= (4/3)*pi*radius**3
print("The volume of a sphere is : %.2f"%volume)
# Out:
# Enter the radius(r) : 3
# The area of the circle is : 28.274
# The volume of a sphere is : 113.10

# %%
#Question 17(16)
import math
from math import pi
radius = float(input ("Enter the radius(r) : "))
height = float(input ("Enter the height(h) : "))
area = ((2*pi*radius*height)+(2*pi*radius**2))
print("The area of a cylinder is : %.1f"%area)
volume = (pi*(radius**2)*height)
print("The volume of a cylinder is : %.1f"%volume)
# Out:
# Enter the radius(r) : 3
# Enter the height(h) : 5
# The area of a cylinder is : 150.8
# The volume of a cylinder is : 141.4

# %%
#Question 18(20)
import math
from math import sqrt
gravity=9.8
initial_velocity=0
height=float(input("Height from which object is dropped(m): "))
velocity=sqrt((initial_velocity**2)+2*gravity*height)
print("Object will hit the ground at %.2f m/s." %velocity)
# Out:
# Height from which object is dropped(m): 100
# Object will hit the ground at 44.27 m/s.

# %%
#Question 19(21)
base = float(input ("Enter the length of base(b) : "))
height = float(input ("Enter the height(h) : "))
area=(base*height)/2
print("Area of the triangle :",area)
# Out:
# Enter the length of base(b) : 5
# Enter the height(h) : 7
# Area of the triangle : 17.5

# %%
#Question 20(22)
import math
from math import sqrt
s1=float(input("Enter the length of the first side : "))
s2=float(input("Enter the length of the second side : "))
s3=float(input("Enter the length of the third side : "))
s = (s1+s2+s3)/2
area = sqrt(s*(s-s1)*(s-s2)*(s-s3))
print("Area of the triangle : %.2f"%area)
# Out:
# Enter the length of the first side : 7
# Enter the length of the second side : 6
# Enter the length of the third side : 5
# Area of the triangle : 14.70

# %%
#Question 21(23)
seconds=int(input("Enter number of seconds : "))
days= seconds//(24*3600)
seconds= seconds%(24*3600)
hours= seconds//3600
seconds= seconds%3600
minutes= seconds//60
seconds= seconds%60
print("The duration is(D:HH:MM:SS):","%d:%02d:%02d:%02d"%(days,hours,minutes,seconds))
# Out:
# Enter number of seconds : 369121517
# The duration is(D:HH:MM:SS): 4272:05:45:17

# %%
#Question 22(24)
import time
now = time.asctime()
print(now)
# Out:
# Sat Jan 21 12:37:11 2023

# %%
#Question 23(25)
air_temp=float(input("Enter the air temperature in degrees : "))
wind_speed=float(input("Entre the wind speed in kilometers per hour : "))
wci = (13.12+0.6215*air_temp-11.37*wind_speed**0.16+0.3965*air_temp*wind_speed**0.16)
if(air_temp<=10 and wind_speed>4.8):
  print("Wind Chill Index is considered Valid")
  print("The Wind Chill Index = %d"%wci)
else:
  print("Wind Chill Index is considered Invalid")
  print("The Wind Chill Index = %d"%wci)
# Out:
# Enter the air temperature in degrees : 10
# Entre the wind speed in kilometers per hour : 4.8
# Wind Chill Index is considered Invalid
# The Wind Chill Index = 9

# %%
#Question 24(26)
celsius=float(input("Enter Temperature(celsius): "))
fahrenheit = (celsius*(9/5))+32
print("Temperature in Fahrenheit = %.2ff"%fahrenheit)
kelvin = celsius+273.15
print("Temperature in Kelvin = %.2fK"%kelvin)
# Out:
# Enter Temperature(celsius): 38
# Temperature in Fahrenheit = 100.40f
# Temperature in Kelvin = 311.15K

# %%
#Question 25(27)
num= int(input("Input numbers(only 4 dighit): "))
no= num//1000
no1= (num-no*1000)//100
no2= (num-no*1000-no1*100)//10
no3= num-no*1000-no1*100-no2*10
no4=no+no1+no2+no3
print("The sum of digits %d +"%no,"%d +"%no1,"%d +"%no2,"%d"%no3,":",no4)
# Out:
# Input numbers(only 4 dighit): 5245
# The sum of digits 5 + 2 + 4 + 5 : 16

# %%
#Question 26(28)
x= int(input("Input first number: "))
y= int(input("Input second number: "))
z= int(input("Input third number: "))
num1=min(x,y,z)
num3=max(x,y,z)
num2= (x+y+z)-num1-num3
print("The max term :",num3)
print("The min term :",num1)
print("The middle term :",num2)
print("Numbers in sorted order: ",num1,num2,num3)
# Out:
# Input first number: 10
# Input second number: 50
# Input third number: 5
# The max term : 50
# The min term : 5
# The middle term : 10
# Numbers in sorted order:  5 10 50

# %%
#Question 27(29)
kilo_pascals= float(input("Enter pressure in kilo_pascals : "))
psi= kilo_pascals/6.89475729
mmhg = kilo_pascals*7.50062
atm = kilo_pascals/101.325
print("The pressure in pounds per square inch: %.2f psi"  % (psi))
print("The pressure in millimeter of mercury: %.2f mmHg" % (mmhg))
print("Atmosphere pressure: %.2f atm." % (atm))
# Out:
# Enter pressure in kilo_pascals : 50
# The pressure in pounds per square inch: 7.25 psi
# The pressure in millimeter of mercury: 375.03 mmHg
# Atmosphere pressure: 0.49 atm.
