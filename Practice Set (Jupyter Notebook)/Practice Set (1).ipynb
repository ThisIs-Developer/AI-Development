# %%
print("HI BHSHIAMADEV")
# Out:
# HI BHSHIAMADEV

# %%
a=10
print(a)
type(a)
# Out:
# 10
# int

# %%
a='baivab sarkar'
print(a)
type(a)
# Out:
# baivab sarkar
# str

# %%
a=8.69
print(a)
type(a)
# Out:
# 8.69
# float

# %%
item='A'
print(item)
ord(item)
# Out:
# A
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
a=10
b=20
if (a<b):
  print('A less then B')
  print('A = 10')
else:
  print('B grater then A')
  print('B = 20')
# Out:
# A less then B
# A = 10

# %%
a=10
b=20
c=30
if(a>b):
  print('A Grater')
elif(b<c):
  print('B grater')
else:
  print('C grater')
# Out:
# B grater

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
c=a-b
print(c)
# Out:
# -10

# %%
c=a*b
print(c)
# Out:
# 200

# %%
c=a/b
print(c)
# Out:
# 0.5

# %%
c=a//b
print(c)
# Out:
# 0

# %%
c=b//a
print(c)
# Out:
# 2

# %%
c=a%b
print(c)
# Out:
# 10

# %%
c=a^b
print(c)
# Out:
# 30

# %%
c=a**b
print(c)
# Out:
# 100000000000000000000

# %%
c=10**1000
print(c)
# Out:
# ...

# %%
a=-1
b=2
c=a and b
print(c)
# Out:
# 2

# %%
a=10
b=20
c=a & b
print(c)
# Out:
# 0

# %%
a=10
b=20
c=a | b
print(c)
# Out:
# 30

# %%
a=-10
b=20
c=a or b
print(c)
# Out:
# -10
