# %%
# %%writefile fast.py
from random import choice
places=["McDonalds", "KFC", "Burger King", "Taco Bell", "Wendys", "Arbys", "Pizza Hut"]
def pick():
  return choice(places)
# Out:
# Writing fast.py

# %%
# !python fast.py

# %%
import fast
places=fast.pick()
print("Lets go to,",places)
# Out:
# Lets go to, Arbys

# %%
# %%writefile lunch.py
import fast
place=fast.pick()
print("Lets go to",place)
# Out:
# Writing lunch.py

# %%
# !python lunch.py
# Out:
# Lets go to Pizza Hut

# %%
# %%writefile fast2.py
places=["McDonalds", "KFC", "Burger King", "Taco Bell", "Wendys", "Arbys", "Pizza Hut"]
def pick():
  import random
  return random.choice(places)
# Out:
# Writing fast2.py

# %%
# %%writefile lunch2.py
import fast2
places=fast2.pick()
print("Lets go to",places)
# Out:
# Writing lunch2.py

# %%
# !python lunch2.py
# Out:
# Lets go to KFC

# %%
# %%writefile fast3.py
import fast2 as f
places=f.pick()
print("Lets go to,",places)
# Out:
# Writing fast3.py

# %%
# !python fast3.py
# Out:
# Lets go to, Taco Bell

# %%
# %%writefile fast4.py
from fast2 import pick
places=pick()
print("Lets go to,",places)
# Out:
# Writing fast4.py

# %%
# !python fast4.py
# Out:
# Lets go to, McDonalds

# %%
# %%writefile ap/ap1.py
def myname():
  print('Apurba sir')

def mysubject():
  print("ML AI Python C++ JAVA")
# Out:
# Writing ap/ap1.py

# %%
# %%writefile ap/ap2.py
def mycollege():
  print('JISCE')
# Out:
# Writing ap/ap2.py

# %%
# %%writefile apurbasir.py
from ap import ap1,ap2
ap1.myname()
ap1.mysubject()
ap2.mycollege()
# Out:
# Writing apurbasir.py

# %%
# !python apurbasir.py
# Out:
# Apurba sir
# ML AI Python C++ JAVA
# JISCE

# %%
# %%writefile choices/fast.py
from random import choice
places=["McDonalds", "KFC", "Burger King", "Taco Bell", "Wendys", "Arbys", "Pizza Hut"]
def pick():
  """Return random fast food places"""
  return choice(places)
# Out:
# Overwriting choices/fast.py

# %%
# %%writefile choices/advice.py
from random import choice
answers=["Yes!", "No!", "Reply Hazy", "Sorry, What?"]
def give():
  """Return random choices"""
  return choice(answers)
# Out:
# Overwriting choices/advice.py

# %%
# %%writefile questions.py
from choices import fast, advice
print("Lets go to,",fast.pick())
print("Should we take out?", advice.give())
# Out:
# Overwriting questions.py

# %%
# !python questions.py
# Out:
# Lets go to, Pizza Hut
# Should we take out? No!

# %%
import sys
for place in sys.path:
  print(place)
# Out:
# /content
# /env/python
# /usr/lib/python39.zip
# /usr/lib/python3.9
# /usr/lib/python3.9/lib-dynload
#
# /usr/local/lib/python3.9/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.9/dist-packages/IPython/extensions
# /root/.ipython

# %%
import sys
sys.path.insert(0,"/choices/apu")

# %%
dir(print())
# Out:
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']
