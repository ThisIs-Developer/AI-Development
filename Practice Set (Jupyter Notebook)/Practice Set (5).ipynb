# %%
def do_nothing():
  pass

# %%
def make_a_sound():
  print('quick')
make_a_sound()
# Out:
# quick

# %%
def agree():
  return True

if agree():
  print('ok')
else:
  print('not ok')
# Out:
# ok

# %%
def func():
  return 0

if func():
  print("india")
else:
  print("OKOKOK")
# Out:
# OKOKOK

# %%
def echo(a):
  return a+' '+a

echo('I am ok')
# Out:
# 'I am ok I am ok'

# %%
def commentary(color):
  if(color=='red'):
    return 'it is tomato'
  elif(color=='green'):
    return 'it is a green paper'
  elif color=='blue':
    return 'i dont know what it is'
  else :
    return 'i dont know the color'

comment=commentary('blue')
print(comment)
# Out:
# i dont know what it is

# %%
print(do_nothing())
# Out:
# None

# %%
var=None
if(var):
  print("RAINY")
else:
  print("HOT")
# Out:
# HOT

# %%
a=10
b=20
a is b
# Out:
# False

# %%
a=[]
a is True
# Out:
# False

# %%
def whatis(thing):
  if thing is None:
    print(thing , 'is NOne')
  elif thing:
    print(thing,'is True')
  else:
    print(thing,'is False')

whatis(None)
whatis(True)
whatis(False)
whatis(0)
whatis(0.0)
whatis("")
whatis('''''')
whatis(())
whatis([])
whatis({})
whatis(set())
whatis(0.00001)
whatis([0])
whatis([''])
whatis(' ')
# Out:
# None is NOne
# True is True
# False is False
# 0 is False
# 0.0 is False
#  is False
#  is False
# () is False
# [] is False
# {} is False
# set() is False
# 1e-05 is True
# [0] is True
# [''] is True
#   is True

# %%
def menu(wine,entry,dessert):
  return {'wine':wine,'entry':entry,'dessert':dessert}

print(menu('chardonnay','chicken','cake'))
print(menu('ayan','bhishma','baivab'))
# Out:
# {'wine': 'chardonnay', 'entry': 'chicken', 'dessert': 'cake'}
# {'wine': 'ayan', 'entry': 'bhishma', 'dessert': 'baivab'}

# %%
menu(wine='baivab',dessert='ayan',entry='baivab')
# Out:
# {'wine': 'baivab', 'entry': 'baivab', 'dessert': 'ayan'}

# %%
menu('jisce','NIT',dessert='JIS')
# Out:
# {'wine': 'jisce', 'entry': 'NIT', 'dessert': 'JIS'}

# %%
def menu(wine,entry,dessert='pudding'):
  return {'wine':wine,'entry':entry,'desert':dessert}


menu('Chardonnay','chiken')
# Out:
# {'wine': 'Chardonnay', 'entry': 'chiken', 'desert': 'pudding'}

# %%
menu('Chardonnay','chiken','hello')
# Out:
# {'wine': 'Chardonnay', 'entry': 'chiken', 'desert': 'hello'}

# %%
def buggy(arg,result=[]):
  result.append(arg)
  print( result);

buggy('a')
buggy('b')
# Out:
# ['a']
# ['a', 'b']

# %%
def nonbuggy(arg,result=None):
  if result is None:
    result=[]
  result.append(arg)
  print(result)

nonbuggy('a')
nonbuggy('b')
# Out:
# ['a']
# ['b']

# %%
def print_arg(*args):
  print(args)

print_arg(())
print_arg('a',9,0,'o')
# Out:
# ((),)
# ('a', 9, 0, 'o')

# %%
def sum(*args):
  sum=0
  for i in args:
    sum=sum+i
  return sum

print(sum(1,2,4))
print(sum(7,9,9))
# Out:
# 7
# 25

# %%
def print_more(r1,r2,*args):
  print('Need this one',r1)
  print('Nedd this one too',r2)
  print('All the rest:',args)

print_more('cap','gloves','scarf','monocle','mustache wax')
# Out:
# Need this one cap
# Nedd this one too gloves
# All the rest: ('scarf', 'monocle', 'mustache wax')

# %%
def print_args(*args):
  print('Positonal tuple' ,args)

print_args(2,5,7,'x')
# Out:
# Positonal tuple (2, 5, 7, 'x')

# %%
args=(2,5,7,'x')
print_args(args)
# Out:
# Positonal tuple ((2, 5, 7, 'x'),)

# %%
def  print_key(**key):
  print('keyword argument:',key)

print_key()
print_key(wine='baivab',entree='ayan',desert='bhsima')
# Out:
# keyword argument: {}
# keyword argument: {'wine': 'baivab', 'entree': 'ayan', 'desert': 'bhsima'}

# %%
def ayan(*args,**key):
  for arg in args:
    print(arg)
  for k,v in key.items():
    print(k,'\t',v)

ayan(1,2,3,4,5,wine='baivab',entre='bhsima',desert='ayn')
# Out:
# 1
# 2
# 3
# 4
# 5
# wine 	 baivab
# entre 	 bhsima
# desert 	 ayn

# %%
def print_data(data,*, start=0,end=100):
  for value in (data[start:end]):
    print(value)

# %%
data=['a','b','c','d']
print_data(data)
# Out:
# a
# b
# c
# d

# %%
print_data(data,start=3)
# Out:
# d

# %%
print_data(data,end=3)
# Out:
# a
# b
# c

# %%
outside=['one','two','three']
def ok(arg):
  arg[1]='terrible'

# %%
outside
# Out:
# ['one', 'two', 'three']

# %%
ok(outside)

# %%
outside
# Out:
# ['one', 'terrible', 'three']

# %%
def print_if_true(thing,check):
  if check:
    print(thing)

# %%
help(echo)
# Out:
# Help on function echo in module __main__:
#
# echo(a)

# %%
print(echo)
