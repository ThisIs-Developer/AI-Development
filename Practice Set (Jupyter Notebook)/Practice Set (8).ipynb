# %%
class Cat():
  pass

# %%
class Cat():
  pass
a_cat=Cat()
a_cat

# %%
another_cat=Cat()
another_cat

# %%
a_cat.age=3
a_cat.name="Baivab Sarkar"
a_cat.nemesis=another_cat
a_cat.age
# Out:
# 3

# %%
a_cat.name
# Out:
# 'Baivab Sarkar'

# %%
a_cat.nemesis

# %%
class Cat:
  def __init__(self):
    pass

# %%
class Cat():
  def __init__(self, name):
    self.name=name

# %%
furball=Cat('Grumpy')

# %%
print('Our latest addition : ',furball.name)
# Out:
# Our latest addition :  Grumpy

# %%
class Car():
  pass
class Yugo(Car):
  pass

# %%
issubclass(Yugo, Car)
# Out:
# True

# %%
give_me_a_car=Car()
give_me_a_yugo=Yugo()

# %%
class Car():
  def exclaim(self):
    print("I'm a Car")
class Yugo(Car):
  pass

# %%
give_me_a_car= Car()
give_me_a_yugo= Yugo()

# %%
give_me_a_car.exclaim()
give_me_a_yugo.exclaim()
# Out:
# I'm a Car
# I'm a Car

# %%
class Car():
  def exclaim(self):
    print("I'm a Car!")

class Yugo(Car):
  def exclaim(self):
    print("I'm a Yugo! Much like a Car,  but more Yugo-ish.")

# %%
give_me_a_car = Car()
give_me_a_yugo = Yugo()

# %%
give_me_a_car.exclaim()
# Out:
# I'm a Car!

# %%
give_me_a_yugo.exclaim()
# Out:
# I'm a Yugo! Much like a Car,  but more Yugo-ish.

# %%
class Person():
  def __init__(self, name):
    self.name = name
class MDPerson(Person):
  def __init__(self, name):
    self.name="Doctor " + name
class JDPerson(Person):
  def __init__(self, name):
    self.name= name+ ", Esquire"

# %%
person = Person('Baivab')
doctor = MDPerson("Baivab")
lawyer = JDPerson('Baivab')

# %%
print(person.name)
print(doctor.name)
print(lawyer.name)
# Out:
# Baivab
# Doctor Baivab
# Baivab, Esquire

# %%
class Car():
  def exclaim(self):
    print("I'm a Car!")
class Yugo(Car):
  def exclaim(Self):
    print("I'm a Yugo! Much like a Car, But more Yugo-ish")
  def need_a_push(self):
    print("A little help herre?")

# %%
give_me_a_car = Car()
give_me_a_yugo = Yugo()

# %%
give_me_a_yugo.need_a_push()
# Out:
# A little help herre?

# %%
class Person():
  def __init__(self, name):
    self.name=name

# %%
class EmailPerson(Person):
  def __init__(self, name,  email):
    super().__init__(name)
    self.email=email

# %%
bob = EmailPerson('Bob Frapple', 'bob@frapples.com')

# %%
bob.name
# Out:
# 'Bob Frapple'

# %%
bob.email
# Out:
# 'bob@frapples.com'

# %%
class EmailPerson(Person):
  def __init__(self, name, email):
    self.name=name
    self.email=email

# %%
class Animal:
  def says(self):
    return 'I speak!'
class Horse(Animal):
  def says(self):
    return 'Neigh!'
class Donkey(Animal):
  def says(self):
    return 'Hee-haw!'
class Mule(Donkey, Horse):
  pass
class Hinny(Horse, Donkey):
  pass

# %%
Mule.mro()
# Out:
# [__main__.Mule, __main__.Donkey, __main__.Horse, __main__.Animal, object]

# %%
Hinny.mro()
# Out:
# [__main__.Hinny, __main__.Horse, __main__.Donkey, __main__.Animal, object]

# %%
mule =Mule()
hinny= Hinny()

# %%
mule.says()
# Out:
# 'Hee-haw!'

# %%
hinny.says()
# Out:
# 'Neigh!'

# %%
a_car = Car()
a_car.exclaim()
# Out:
# I'm a Car!

# %%
Car.exclaim(a_car)
# Out:
# I'm a Car!

# %%
class Duck:
  def __init__(self,input_name):
    self.name= input_name
fowl=Duck('Daffy')
fowl.name
# Out:
# 'Daffy'

# %%
fowl.name='Baivab'
fowl.name
# Out:
# 'Baivab'

# %%
class Duck():
  def __init__(self,input_name):
    self.hidden_name=input_name
  def get_name(self):
    print('inside the getter')
    return self.hidden_name
  def set_name(self,input_name):
    print('inside the setter')
    self.hidden_name=input_name

don=Duck('Baivab')
don.get_name()
# Out:
# inside the getter
# 'Baivab'

# %%
don.set_name('Baivab')
# Out:
# inside the setter

# %%
don.get_name()
# Out:
# inside the getter
# 'Baivab'

# %%
class Apu:
  def __init__(self,myname):
    self.mname=myname

# %%
a=Apu('Baivab')
a.mname
# Out:
# 'Baivab'

# %%
class Duck():
  def __init__(self,input_name):
    self.hidden_name=input_name
  def get_name(self):
    print('inside the getter')
    return self.hidden_name
  def set_name(self,input_name):
    print('inside the setter')
    self.hidden_name=input_name
  name= property(get_name,set_name)

# %%
don=Duck('Baivab')
don.get_name()
# Out:
# inside the getter
# 'Baivab'

# %%
don.set_name('Baivab')
# Out:
# inside the setter

# %%
don.get_name()
# Out:
# inside the getter
# 'Baivab'

# %%
don=Duck('Baivab')

# %%
don.name
# Out:
# inside the getter
# 'Baivab'

# %%
don.name='Baivab'
# Out:
# inside the setter

# %%
don.name
# Out:
# inside the getter
# 'Baivab'

# %%
class Duck():
  def __init__(self,input_name):
    self.hidden_name=input_name
  @property
  def name(self):
    print('inside the getter')
    return self.hidden_name
  @name.setter
  def name(self,input_name):
    print('inside the setter')
    self.hidden_name=input_name

# %%
fowl=Duck('Baivab')

# %%
fowl.name
# Out:
# inside the getter
# 'Baivab'

# %%
fowl.name='Biavab'
# Out:
# inside the setter

# %%
fowl.name
# Out:
# inside the getter
# 'Biavab'

# %%
class Circle():
  def __init__(self,radius):
    self.radius=radius
  @property
  def diameter(self):
    return 2*self.radius

# %%
c=Circle(5)
c.radius
# Out:
# 5

# %%
c.diameter
# Out:
# 10

# %%
c.radius=7
c.diameter
# Out:
# 14

# %%
class Duck():
  def __init__(self,input_name):
    self.__name=input_name
  @property
  def name(self):
    print('inside the getter')
    return self.__name
  @name.setter
  def name(self,input_name):
    print('inside the setter')
    self.__name=input_name

# %%
fowl=Duck('Baivab')

# %%
fowl.name
# Out:
# inside the getter
# 'Baivab'

# %%
fowl.name='Baivab'
# Out:
# inside the setter

# %%
fowl.name
# Out:
# inside the getter
# 'Baivab'

# %%
fowl._Duck__name
# Out:
# 'Baivab'

# %%
class Fruit:
  color='red'

# %%
blueberry=Fruit()

# %%
Fruit.color
# Out:
# 'red'

# %%
blueberry.color
# Out:
# 'red'

# %%
blueberry.color='Blue'
blueberry.color
# Out:
# 'Blue'

# %%
Fruit.color
# Out:
# 'red'

# %%
Fruit.color='Orange'
Fruit.color
blueberry.color
# Out:
# 'Blue'

# %%
new_fruit=Fruit()
new_fruit.color
# Out:
# 'Orange'

# %%
class A():
  count=0
  def __init__(self):
    A.count+=1
  def exclaim(self):
    print("I'm an A!")
  @classmethod
  def kids(cls):
    print("A has",cls.count,"little object.")

# %%
easy_a=A()

# %%
breezy_a=A()

# %%
wheezy_a=A()

# %%
A.kids()
# Out:
# A has 3 little object.

# %%
class coyoteWeapon():
  @staticmethod
  def commercial():
    print('This coyoteWeapon has been brought to you by baivab')

# %%
coyoteWeapon.commercial()
# Out:
# This coyoteWeapon has been brought to you by baivab

# %%
class Word():
  def __init__(self, text):
    self.text=text
  def equals(self,word2):
    return self.text.lower() == word2.text.lower()

# %%
first = Word('ha')
second = Word('HA')
third = Word('eh')

# %%
first.equals(second)
# Out:
# True

# %%
first.equals(third)
# Out:
# False

# %%
class Word():
  def __init__(self, text):
    self.text=text
  def __eq__(self,word2):
    return self.text.lower()==word2.text.lower()

# %%
first=Word('ha')
second=Word('HA')
third= Word('eh')
first==second
# Out:
# True

# %%
first==third
# Out:
# False
